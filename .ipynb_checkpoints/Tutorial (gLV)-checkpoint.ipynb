# %%
import numpy as np
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import time

# import functions for ODE parameter estimation
from bayes_ode import *
import jax.numpy as jnp

np.random.seed(123)

# %% [markdown]
# ## Parameter estimation of ODE models:
#
# $$
# \frac{d \mathbf{x}}{d t} = f(\mathbf{x}, t, \theta)
# $$
# where $\mathbf{x}$ is a vector of state variables and $\theta$ is a vector of model parameters to be estimated from data

# %% [markdown]
# ## Define ODE (x, time, parameters)

# %%
# using gLV model as an example
def system(x, t, u, params): 
    
    # reshape parameters
    r = params[:n_s]
    A = jnp.reshape(params[n_s:], [n_s, n_s])
    
    # constrained gLV 
    return x * (r + A@x)

# %% [markdown]
# ## Import data as a Pandas dataframe
#
# The dataframe must have a "Treatments" column that provides a unique identifier for each condition. The second column specifies the time point that observations were made. The following columns include the state variables.

# %%
# data from https://www.nature.com/articles/s41467-024-51062-w
df = pd.read_csv("data/MS008_processed.csv")
df = pd.concat([df_i for exp_name, df_i in df.groupby("Treatments") if "Mono" not in exp_name])
df
# Out:
#               Treatments  Time        CA        BT        BU   CS        CD  \
# 87           CH-DP-BT-BU   0.0  0.000000  0.002500  0.002500  0.0  0.000000
# 88           CH-DP-BT-BU  12.0  0.000000  0.726639  0.316787  0.0  0.000000
# 89           CH-DP-BT-BU  24.0  0.000000  0.633990  0.211766  0.0  0.000000
# 90           CH-DP-BU-CA   0.0  0.002500  0.000000  0.002500  0.0  0.000000
# 91           CH-DP-BU-CA  12.0  0.002391  0.000000  0.890796  0.0  0.000000
# ..                   ...   ...       ...       ...       ...  ...       ...
# 82  MS008-DP-BT-BU-BV-CA  12.0  0.003568  0.752347  0.126277  0.0  0.307087
# 83  MS008-DP-BT-BU-BV-CA  24.0  0.065093  0.771636  0.155679  0.0  0.055671
# 84        MS008-DP-BU-CA   0.0  0.002500  0.000000  0.002500  0.0  0.002500
# 85        MS008-DP-BU-CA  12.0  0.006165  0.000000  0.469328  0.0  0.415756
# 86        MS008-DP-BU-CA  24.0  0.123855  0.000000  0.428663  0.0  0.042363
#
#           DP        CH        BV
# 87  0.002500  0.002500  0.000000
# 88  0.036658  0.111416  0.000000
# 89  0.064840  0.106737  0.000000
# 90  0.002500  0.002500  0.000000
# 91  0.055984  0.142329  0.000000
# ..       ...       ...       ...
# 82  0.041542  0.000000  0.142012
# 83  0.103377  0.000000  0.055543
# 84  0.002500  0.000000  0.000000
# 85  0.049418  0.000000  0.000000
# 86  0.192452  0.000000  0.000000
#
# [177 rows x 10 columns]

# %% [markdown]
# ## Specify system state variables

# %%
# names of species
species = df.columns.values[2:]
inputs = []

# global parameters used in ODE
n_s = len(species)

# %% [markdown]
# ## Define mean and standard deviation of Gaussian parameter prior

# %%
# define initial parameter guess
n_params = n_s + n_s**2 
params = np.zeros(n_params)

# initial guess of growth rates
params[:n_s] = .3

# initial guess of self interaction terms
k = 0
for i in range(n_s):
    for j in range(n_s):
        if i == j:
            params[n_s+k] = -1.
        k += 1

# mean of parameter prior is zero
prior = np.zeros(n_params)

# %% [markdown]
# ## Instantiate the model with the ODE function, training dataframe, system variables, and initial parameter guess

# %%
# instantiate gLV fit 
model = Model(system = system, 
              dataframe = df, 
              sys_vars = species,
              inputs = inputs,
              params = params,
              prior = prior, 
              alpha=1., nu2=.001, sigma2=.001)

# %% [markdown]
# ## Fit the parameter posterior

# %%
# fit to data 
t0 = time.time()

model.fit_posterior_EM(lr=1e-3,
                       n_sample_sgd=5, 
                       n_sample_hypers=100,
                       patience=3)

print("Elapsed time {:.2f}s".format(time.time()-t0))
# Out:
# Updating posterior...
# Epoch 0, ELBO: -18685.680, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: -2329.017, Slope: 1.000, Convergence: 0.77834
# Epoch 10, ELBO: -298.818, Slope: 0.159, Convergence: 0.95794
# Epoch 15, ELBO: 354.594, Slope: 0.167, Convergence: 1.06767
# Epoch 20, ELBO: 714.142, Slope: 0.171, Convergence: 1.17638
# Epoch 25, ELBO: 936.332, Slope: 0.173, Convergence: 1.29096
# Epoch 30, ELBO: 1101.440, Slope: 0.174, Convergence: 1.42347
# Epoch 35, ELBO: 1230.924, Slope: 0.163, Convergence: 1.58007
# Epoch 40, ELBO: 1333.105, Slope: 0.148, Convergence: 1.76699
# Epoch 45, ELBO: 1427.819, Slope: 0.133, Convergence: 2.00443
# Epoch 50, ELBO: 1485.433, Slope: 0.227, Convergence: 1.49403
# Epoch 55, ELBO: 1548.925, Slope: 0.107, Convergence: 0.57509
# Epoch 60, ELBO: 1606.865, Slope: 0.070, Convergence: 0.36876
# Epoch 65, ELBO: 1626.290, Slope: 0.050, Convergence: 0.24991
# Epoch 70, ELBO: 1684.529, Slope: 0.039, Convergence: 0.20481
# Epoch 75, ELBO: 1704.354, Slope: 0.031, Convergence: 0.15552
# Epoch 80, ELBO: 1738.840, Slope: 0.026, Convergence: 0.13006
# Epoch 85, ELBO: 1762.083, Slope: 0.021, Convergence: 0.10696
# Epoch 90, ELBO: 1778.036, Slope: 0.017, Convergence: 0.08661
# Epoch 95, ELBO: 1809.858, Slope: 0.015, Convergence: 0.08082
# Epoch 100, ELBO: 1827.381, Slope: 0.013, Convergence: 0.06945
# Epoch 105, ELBO: 1845.395, Slope: 0.011, Convergence: 0.06157
# Epoch 110, ELBO: 1857.372, Slope: 0.011, Convergence: 0.05328
# Epoch 115, ELBO: 1866.747, Slope: 0.009, Convergence: 0.04436
# Epoch 120, ELBO: 1882.305, Slope: 0.008, Convergence: 0.04154
# Epoch 125, ELBO: 1888.886, Slope: 0.007, Convergence: 0.03461
# Epoch 130, ELBO: 1901.824, Slope: 0.006, Convergence: 0.03248
# Epoch 135, ELBO: 1914.208, Slope: 0.006, Convergence: 0.03069
# Epoch 140, ELBO: 1926.720, Slope: 0.005, Convergence: 0.02919
# Epoch 145, ELBO: 1935.615, Slope: 0.005, Convergence: 0.02704
# Epoch 150, ELBO: 1938.409, Slope: 0.004, Convergence: 0.02250
# Epoch 155, ELBO: 1946.612, Slope: 0.004, Convergence: 0.02138
# Epoch 160, ELBO: 1951.404, Slope: 0.004, Convergence: 0.01886
# Epoch 165, ELBO: 1957.630, Slope: 0.003, Convergence: 0.01729
# Epoch 170, ELBO: 1963.250, Slope: 0.003, Convergence: 0.01594
# Epoch 175, ELBO: 1961.154, Slope: 0.003, Convergence: 0.01107
# pass 1
# Epoch 180, ELBO: 1900.382, Slope: 0.000, Convergence: -0.02019
# Epoch 185, ELBO: 1975.873, Slope: 0.002, Convergence: 0.01550
# Epoch 190, ELBO: 1966.901, Slope: 0.001, Convergence: 0.00881
# pass 1
# Epoch 195, ELBO: 1963.736, Slope: 0.001, Convergence: 0.00574
# Epoch 200, ELBO: 1977.092, Slope: 0.001, Convergence: 0.01058
# pass 1
# Epoch 205, ELBO: 1973.259, Slope: 0.001, Convergence: 0.00724
# Epoch 210, ELBO: 1998.451, Slope: 0.002, Convergence: 0.01766
# Epoch 215, ELBO: 2001.325, Slope: 0.002, Convergence: 0.01686
# Epoch 220, ELBO: 1981.928, Slope: 0.002, Convergence: 0.00605
# Epoch 225, ELBO: 2001.865, Slope: 0.004, Convergence: 0.01407
# Epoch 230, ELBO: 1999.536, Slope: 0.001, Convergence: 0.00783
# Epoch 235, ELBO: 2006.679, Slope: 0.002, Convergence: 0.00986
# Epoch 240, ELBO: 2000.573, Slope: 0.002, Convergence: 0.00509
# Epoch 245, ELBO: 2011.149, Slope: 0.001, Convergence: 0.00800
# Epoch 250, ELBO: 2014.109, Slope: 0.002, Convergence: 0.00761
# pass 1
# Epoch 255, ELBO: 2016.985, Slope: 0.001, Convergence: 0.00685
# pass 2
# Epoch 260, ELBO: 1993.883, Slope: 0.000, Convergence: -0.00445
# Epoch 265, ELBO: 2015.145, Slope: 0.001, Convergence: 0.00547
# pass 1
# Epoch 270, ELBO: 2021.847, Slope: 0.001, Convergence: 0.00681
# pass 2
# Epoch 275, ELBO: 2018.803, Slope: 0.001, Convergence: 0.00444
# pass 3
# Epoch 280, ELBO: 2015.119, Slope: 0.000, Convergence: 0.00183
# Updating hyperparameters...
# 100%|█████████████████████████████████████████| 100/100 [00:07<00:00, 13.84it/s]
# Updating posterior...
# Epoch 0, ELBO: 2500.728, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: 2539.956, Slope: 1.000, Convergence: 0.00778
# Epoch 10, ELBO: 2558.744, Slope: 0.002, Convergence: 0.01011
# Epoch 15, ELBO: 2563.269, Slope: 0.002, Convergence: 0.00889
# Epoch 20, ELBO: 2571.575, Slope: 0.003, Convergence: 0.00971
# Epoch 25, ELBO: 2573.628, Slope: 0.003, Convergence: 0.00875
# Epoch 30, ELBO: 2578.369, Slope: 0.003, Convergence: 0.00907
# Epoch 35, ELBO: 2577.761, Slope: 0.003, Convergence: 0.00772
# Epoch 40, ELBO: 2579.467, Slope: 0.003, Convergence: 0.00745
# Epoch 45, ELBO: 2584.400, Slope: 0.003, Convergence: 0.00843
# Epoch 50, ELBO: 2583.671, Slope: 0.001, Convergence: 0.00490
# pass 1
# Epoch 55, ELBO: 2584.197, Slope: 0.001, Convergence: 0.00337
# pass 2
# Epoch 60, ELBO: 2584.064, Slope: 0.001, Convergence: 0.00234
# pass 3
# Epoch 65, ELBO: 2585.590, Slope: 0.000, Convergence: 0.00206
# Updating hyperparameters...
# 100%|█████████████████████████████████████████| 100/100 [00:08<00:00, 12.10it/s]
# Updating posterior...
# Epoch 0, ELBO: 2578.501, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: 2581.615, Slope: 1.000, Convergence: 0.00060
# pass 1
# Epoch 10, ELBO: 2588.172, Slope: 0.000, Convergence: 0.00209
# pass 2
# Epoch 15, ELBO: 2587.953, Slope: 0.000, Convergence: 0.00151
# pass 3
# Epoch 20, ELBO: 2584.121, Slope: 0.000, Convergence: 0.00002
# Updating hyperparameters...
# 100%|█████████████████████████████████████████| 100/100 [00:08<00:00, 11.42it/s]
# Updating posterior...
# Epoch 0, ELBO: 2590.135, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: 2595.863, Slope: 1.000, Convergence: 0.00110
# pass 1
# Epoch 10, ELBO: 2593.527, Slope: 0.000, Convergence: 0.00014
# pass 2
# Epoch 15, ELBO: 2597.823, Slope: 0.000, Convergence: 0.00134
# pass 3
# Epoch 20, ELBO: 2597.802, Slope: 0.000, Convergence: 0.00107
# Updating hyperparameters...
# 100%|█████████████████████████████████████████| 100/100 [00:09<00:00, 11.09it/s]
# Updating posterior...
# Epoch 0, ELBO: 2587.894, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: 2591.617, Slope: 1.000, Convergence: 0.00072
# pass 1
# Epoch 10, ELBO: 2591.063, Slope: 0.000, Convergence: 0.00034
# pass 2
# Epoch 15, ELBO: 2593.191, Slope: 0.000, Convergence: 0.00087
# pass 3
# Epoch 20, ELBO: 2594.852, Slope: 0.000, Convergence: 0.00121
# Updating hyperparameters...
# 100%|█████████████████████████████████████████| 100/100 [00:07<00:00, 12.86it/s]
# Updating posterior...
# Epoch 0, ELBO: 2567.533, Slope: 1.000, Convergence: 0.00000
# Epoch 5, ELBO: 2565.693, Slope: 1.000, Convergence: -0.00036
# pass 1
# Epoch 10, ELBO: 2572.153, Slope: 0.000, Convergence: 0.00144
# pass 2
# Epoch 15, ELBO: 2571.340, Slope: 0.000, Convergence: 0.00084
# pass 3
# Epoch 20, ELBO: 2573.380, Slope: 0.000, Convergence: 0.00131
# Elapsed time 729.15s

# %%
model.nu2
# Out:
# array([0.00025644, 0.0001    , 0.0001    , 0.00026985, 0.00810375,
#        0.0001    , 0.00135306, 0.00462511])

# %%
model.sigma2
# Out:
# array([0.27829576, 0.04252067, 0.08119042, 0.02371649, 0.0338432 ,
#        0.24440174, 0.01879088, 0.06212178])

# %%
# random conditions to plot
plt_conditions = np.random.choice(np.unique(df.Treatments.values), 10, replace=False)

for exp_name in plt_conditions:
    # pull dataframe
    exp_df = df.iloc[df.Treatments.values==exp_name].copy()
    
    # predict values
    x0 = exp_df[species].values[0]
    u = np.array([])
    t_eval = np.linspace(0., max(exp_df.Time.values))
    y_preds = model.predict_sample(x0, u, t_eval)

    # plot 
    for i, s in enumerate(species):
        plt.scatter(exp_df.Time.values, exp_df[s].values)
        for y_pred in y_preds:
            plt.plot(t_eval, y_pred[:, i], alpha=.3, c=f'C{i}')
    
    plt.title(exp_name)
    plt.show()

# %% [markdown]
# ## Save parameter values

# %%
# Define names of parameters 
df_params = model.param_df()
df_params
# Out:
#         mean      stdv
# 0   0.104868  0.004734
# 1   0.861811  0.006145
# 2   0.754190  0.004926
# 3   0.511615  0.005797
# 4   0.908157  0.011888
# ..       ...       ...
# 67  0.752881  0.172042
# 68 -0.539097  0.072821
# 69 -1.281048  0.223717
# 70 -0.637395  0.100249
# 71 -1.082375  0.035306
#
# [72 rows x 2 columns]
